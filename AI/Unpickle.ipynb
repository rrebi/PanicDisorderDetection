# %%
# Define the new instance
new_instance = pd.DataFrame({
    'Age': [38],
    'Gender': ['Male'],
    'Family History': ['Yes'],
    'Personal History': ['Yes'],
    'Current Stressors': ['High'],
    'Symptoms': ['Panic attacks'],
    'Severity': ['Severe'],
    'Impact on Life': ['Mild'],
    'Demographics': ['Rural'],
    'Medical History': ['Diabetes'],
    'Psychiatric History': ['Anxiety disorder'],
    'Substance Use': ['Drugs'],
    'Coping Mechanisms': ['Seeking therapy'],
    'Social Support': ['High'],
    'Lifestyle Factors': ['Sleep quality']
})

# Ensure the new instance has all the features in the same order as the training data
feature_order = [
    'Age', 'Gender', 'Family History', 'Personal History', 'Current Stressors',
    'Symptoms', 'Severity', 'Impact on Life', 'Demographics', 'Medical History',
    'Psychiatric History', 'Substance Use', 'Coping Mechanisms', 'Social Support',
    'Lifestyle Factors'
]

# Reorder the new instance columns
new_instance = new_instance[feature_order]

# Load the pipeline and encoders from the pickle file
with open('xgb_model.pkl', 'rb') as file:
    pipeline_xgb_tuned, label_encoders, imputer_cat, imputer_num = pickle.load(file)

# Apply imputation to the new instance
new_instance[categorical_features] = imputer_cat.transform(new_instance[categorical_features])
new_instance[numerical_features] = imputer_num.transform(new_instance[numerical_features])

# Apply label encoding to the new instance using the stored encoders
for col in categorical_features:
    le = label_encoders[col]
    new_instance[col] = le.transform(new_instance[col])

# Use the pipeline to predict the class for the new instance
xgb_tuned_prediction = pipeline_xgb_tuned.predict(new_instance)

# Print the prediction
print(f"Prediction for the new instance using Tuned XGBoost: {xgb_tuned_prediction[0]}")
# Out:
# Prediction for the new instance using Tuned XGBoost: 1

# %%
# Define the new instance
new_instance = pd.DataFrame({
    'Age': [38],
    'Gender': ['Male'],
    'Family History': ['Yes'],
    'Personal History': ['Yes'],
    'Current Stressors': ['High'],
    'Symptoms': ['Panic attacks'],
    'Severity': ['Severe'],
    'Impact on Life': ['Mild'],
    'Demographics': ['Rural'],
    'Medical History': ['Diabetes'],
    'Psychiatric History': ['Anxiety disorder'],
    'Substance Use': ['Drugs'],
    'Coping Mechanisms': ['Seeking therapy'],
    'Social Support': ['High'],
    'Lifestyle Factors': ['Sleep quality']
})

# Ensure the new instance has all the features in the same order as the training data
feature_order = [
    'Age', 'Gender', 'Family History', 'Personal History', 'Current Stressors',
    'Symptoms', 'Severity', 'Impact on Life', 'Demographics', 'Medical History',
    'Psychiatric History', 'Substance Use', 'Coping Mechanisms', 'Social Support',
    'Lifestyle Factors'
]

# Reorder the new instance columns
new_instance = new_instance[feature_order]

# Load the pipeline and encoders from the pickle file
with open('dtc_model.pkl', 'rb') as file:
    pipeline_dt_pruned, label_encoders, imputer_cat, imputer_num = pickle.load(file)

# Apply imputation to the new instance
new_instance[categorical_features] = imputer_cat.transform(new_instance[categorical_features])
new_instance[numerical_features] = imputer_num.transform(new_instance[numerical_features])

# Apply label encoding to the new instance using the stored encoders
for col in categorical_features:
    le = label_encoders[col]
    new_instance[col] = le.transform(new_instance[col])

# Use the pipeline to predict the class for the new instance
dt_prunded_prediction = pipeline_dt_pruned.predict(new_instance)

# Print the prediction
print(f"Prediction for the new instance using Tuned DT: {dt_prunded_prediction[0]}")
# Out:
# Prediction for the new instance using Tuned DT: 1

# %%
# Define the new instance
new_instance = pd.DataFrame({
    'Age': [38],
    'Gender': ['Male'],
    'Family History': ['No'],
    'Personal History': ['Yes'],
    'Current Stressors': ['Low'],
    'Symptoms': ['Panic attacks'],
    'Severity': ['Severe'],
    'Impact on Life': ['Mild'],
    'Demographics': ['Urban'],
    'Medical History': ['Diabetes'],
    'Psychiatric History': ['Anxiety disorder'],
    'Substance Use': ['Alcohol'],
    'Coping Mechanisms': ['Exercise'],
    'Social Support': ['High'],
    'Lifestyle Factors': ['Sleep quality']
})

# Ensure the new instance has all the features in the same order as the training data
feature_order = [
    'Age', 'Gender', 'Family History', 'Personal History', 'Current Stressors',
    'Symptoms', 'Severity', 'Impact on Life', 'Demographics', 'Medical History',
    'Psychiatric History', 'Substance Use', 'Coping Mechanisms', 'Social Support',
    'Lifestyle Factors'
]

# Reorder the new instance columns
new_instance = new_instance[feature_order]

# Load the pipeline and encoders from the pickle file
with open('xgb_model.pkl', 'rb') as file:
    pipeline_xgb_tuned, label_encoders, imputer_cat, imputer_num = pickle.load(file)

# Apply imputation to the new instance
new_instance[categorical_features] = imputer_cat.transform(new_instance[categorical_features])
new_instance[numerical_features] = imputer_num.transform(new_instance[numerical_features])

# Apply label encoding to the new instance using the stored encoders
for col in categorical_features:
    le = label_encoders[col]
    new_instance[col] = le.transform(new_instance[col])

# Use the pipeline to predict the class for the new instance
xgb_tuned_prediction = pipeline_xgb_tuned.predict(new_instance)

# Print the prediction
print(f"Prediction for the new instance using Tuned XGBoost: {xgb_tuned_prediction[0]}")
# Out:
# Prediction for the new instance using Tuned XGBoost: 0

# %%
print(f"df:{new_instance}")
# Out:
# df:    Age  Gender  Family History  Personal History  Current Stressors  \
# 0  38.0       1               0                 1                  1
#
#    Symptoms  Severity  Impact on Life  Demographics  Medical History  \
# 0         3         2               0             1                1
#
#    Psychiatric History  Substance Use  Coping Mechanisms  Social Support  \
# 0                    0              0                  0               0
#
#    Lifestyle Factors
# 0                  2

# %%
# Define the new instance
new_instance = pd.DataFrame({
    'Age': [38],
    'Gender': ['Male'],
    'Family History': ['Yes'],
    'Personal History': ['Yes'],
    'Current Stressors': ['High'],
    'Symptoms': ['Panic attacks'],
    'Severity': ['Severe'],
    'Impact on Life': ['Mild'],
    'Demographics': ['Rural'],
    'Medical History': ['Diabetes'],
    'Psychiatric History': ['Anxiety disorder'],
    'Substance Use': ['Drugs'],
    'Coping Mechanisms': ['Seeking therapy'],
    'Social Support': ['High'],
    'Lifestyle Factors': ['Sleep quality']
})

# Ensure the new instance has all the features in the same order as the training data
feature_order = [
    'Age', 'Gender', 'Family History', 'Personal History', 'Current Stressors',
    'Symptoms', 'Severity', 'Impact on Life', 'Demographics', 'Medical History',
    'Psychiatric History', 'Substance Use', 'Coping Mechanisms', 'Social Support',
    'Lifestyle Factors'
]

# Reorder the new instance columns
new_instance = new_instance[feature_order]

# Load the pipeline and encoders from the pickle file
with open('dtc_model.pkl', 'rb') as file:
    pipeline_dt_pruned, label_encoders, imputer_cat, imputer_num = pickle.load(file)

# Apply imputation to the new instance
# new_instance[categorical_features] = imputer_cat.transform(new_instance[categorical_features])
# new_instance[numerical_features] = imputer_num.transform(new_instance[numerical_features])

# Apply label encoding to the new instance using the stored encoders
for col in categorical_features:
    le = label_encoders[col]
    new_instance[col] = le.transform(new_instance[col])

# Use the pipeline to predict the class for the new instance
dt_prunded_prediction = pipeline_dt_pruned.predict(new_instance)

# Print the prediction
print(f"Prediction for the new instance using Tuned DT: {dt_prunded_prediction[0]}")
# print(f"df:{new_instance}")
# Out:
# Prediction for the new instance using Tuned DT: 1

# %%
import pandas as pd

# Define the new instance
new_instance = pd.DataFrame({
    'Age': [38],
    'Gender': ['Male'],
    'Family History': ['No'],
    'Personal History': ['Yes'],
    'Current Stressors': ['Low'],
    'Symptoms': ['Panic attacks'],
    'Severity': ['Severe'],
    'Impact on Life': ['Mild'],
    'Demographics': ['Urban'],
    'Medical History': ['Diabetes'],
    'Psychiatric History': ['Anxiety disorder'],
    'Substance Use': ['Alcohol'],
    'Coping Mechanisms': ['Exercise'],
    'Social Support': ['High'],
    'Lifestyle Factors': ['Sleep quality']
})

# Ensure the new instance has all the features in the same order as the training data
feature_order = [
    'Age', 'Gender', 'Family History', 'Personal History', 'Current Stressors',
    'Symptoms', 'Severity', 'Impact on Life', 'Demographics', 'Medical History',
    'Psychiatric History', 'Substance Use', 'Coping Mechanisms', 'Social Support',
    'Lifestyle Factors'
]

# Reorder the new instance columns
new_instance = new_instance[feature_order]

# Make a prediction using the loaded pipeline
prediction = pipeline_svm.predict(new_instance)

print(f'Prediction for the new instance: {prediction[0]}')
# Out:
# Prediction for the new instance: 0

# %%
# Define the new instance
new_instance = pd.DataFrame({
    'Age': [38],
    'Gender': ['Male'],
    'Family History': ['Yes'],
    'Personal History': ['Yes'],
    'Current Stressors': ['High'],
    'Symptoms': ['Panic attacks'],
    'Severity': ['Severe'],
    'Impact on Life': ['Mild'],
    'Demographics': ['Rural'],
    'Medical History': ['Diabetes'],
    'Psychiatric History': ['Anxiety disorder'],
    'Substance Use': ['Drugs'],
    'Coping Mechanisms': ['Seeking therapy'],
    'Social Support': ['High'],
    'Lifestyle Factors': ['Sleep quality']
})

# Ensure the new instance has all the features in the same order as the training data
feature_order = [
    'Age', 'Gender', 'Family History', 'Personal History', 'Current Stressors',
    'Symptoms', 'Severity', 'Impact on Life', 'Demographics', 'Medical History',
    'Psychiatric History', 'Substance Use', 'Coping Mechanisms', 'Social Support',
    'Lifestyle Factors'
]

# Reorder the new instance columns
new_instance = new_instance[feature_order]

# Load the pipeline and encoders from the pickle file
with open('dtc_model.pkl', 'rb') as file:
    pipeline_dt_pruned, label_encoders = pickle.load(file)

# Apply imputation to the new instance
# new_instance[categorical_features] = imputer_cat.transform(new_instance[categorical_features])
# new_instance[numerical_features] = imputer_num.transform(new_instance[numerical_features])

# Apply label encoding to the new instance using the stored encoders
for col in categorical_features:
    le = label_encoders[col]
    new_instance[col] = le.transform(new_instance[col])

# Use the pipeline to predict the class for the new instance
dt_prunded_prediction = pipeline_dt_pruned.predict(new_instance)

# Print the prediction
print(f"Prediction for the new instance using Tuned DT: {dt_prunded_prediction[0]}")
# print(f"df:{new_instance}")
# Out:
# Prediction for the new instance using Tuned DT: 1
